# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configuramos el estilo para reportes senior
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# Cargamos el dataset unificado (ajusta la ruta si es necesario)
# df_maestro = pd.read_csv('data/df_maestro_fitness.csv') # Ejemplo si lo guardaste en disco
print(f"✅ Dataset cargado. Registros: {len(df_maestro)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       7 plt.rcParams['figure.figsize'] = (12, 6)
#       9 # Cargamos el dataset unificado (ajusta la ruta si es necesario)
#      10 # df_maestro = pd.read_csv('data/df_maestro_fitness.csv') # Ejemplo si lo guardaste en disco
# ---> 11 print(f"✅ Dataset cargado. Registros: {len(df_maestro)}")
#
# NameError: name 'df_maestro' is not defined
